# %% [markdown]
# # Demonstration Notebook: Spectrum 1D
#
# This notebook demonstrates the generalized app API when looking at 1D Spectra in the Notebook setting. This notebook follows the examples of the SpecvizExample notebook and refers to the plugins used by Specviz. UI equivalents for these actions, as well as additional documentation about the Specviz configuration generally, can be found here: https://jdaviz.readthedocs.io/en/latest/specviz/. These generalized workflows are supported as of Jdaviz v5.0.
#
# ### PLEASE NOTE
# Running cells in rapid succession may cause errors or other bugs in the app. If these occur, you may need to rerun the cell or otherwise restart the notebook.

# %%
import warnings
# Ignore warnings when loading data
warnings.simplefilter('ignore')

# %% [markdown]
# ## Launch App
#
# We create a Jdaviz app instance.
#
# Multiple Jdaviz app instances can be created and used simultaneously if desired. See https://jdaviz.readthedocs.io/en/latest/quickstart.html#multiple-jdaviz-instances for more details.

# %%
# Calling jd will implicitly create a jdaviz app instance
import jdaviz as jd

# Another option is to use gca() which refers to 'get current app'.
# It is not strictly necessary here but can be useful
# if multiple instances of the app are instantiated.
# jd = jdaviz.gca()

# %% [markdown]
# ## Display App
#
# This will show the app inline in the notebook. You can pass an integer to the `height` keyword to change the displayed height of the app (the default is 600). You can also pass `loc="popout:window"` to immediately pop out the Jdaviz app into a separate window.

# %%
jd.show()

# %% [markdown]
# ## Load Data into the App
#
# Now we load observations. If you already have the files on your local machine, you can
# load them by passing their file paths to `load` as strings. For this example,
# we will retrieve remote data from [MAST](https://mast.stsci.edu/) via `astroquery`
# by passing the observation's URI as a string. By default, the downloaded files are
# saved to the current working directory. If you set `cache=False` in the `load`
# call, it will re-download the file if desired.
#
# Note, when retrieving MAST data through astroquery, it is cached by default.
# It is possible for files to be updated in MAST with more recent calibrations
# but remain the same size, in which case your local cached file would not be replaced by the new
# version. Again, you can turn off caching by setting `cache=False` to force it to re-download the
# file.

# %%
uri = 'mast:JWST/product/jw02732-c1001_t004_miri_ch1-short_x1d.fits'
data_label = 'my_spectrum'
jd.load(uri, format='1D Spectrum', data_label=data_label, cache=True)

# %% [markdown]
# ## Retrieve Data and Subsets (and sometimes both!)
#
# ### User Task
#
# Click on the region selection tool (<img src="data:image/svg+xml;utf8,<svg%20xmlns%3D%22http://www.w3.org/2000/svg%22%20id%3D%22Layer_1%22%20data-name%3D%22Layer%201%22%20viewBox%3D%220%200%2022.76%2024%22><defs%20/><rect%20x%3D%221.96%22%20y%3D%2216.15%22%20width%3D%222.96%22%20height%3D%222.96%22%20rx%3D%221.48%22%20fill%3D%22%23000000%22%20stroke%3D%22%23ffffff%22%20stroke-width%3D%221.75%22%20stroke-linecap%3D%22round%22%20stroke-linejoin%3D%22round%22%20vector-effect%3D%22non-scaling-stroke%22%20style%3D%22paint-order:%20stroke%20fill%22%20/><rect%20x%3D%2218%22%20y%3D%2211.77%22%20width%3D%222.96%22%20height%3D%222.96%22%20rx%3D%221.48%22%20fill%3D%22%23000000%22%20stroke%3D%22%23ffffff%22%20stroke-width%3D%221.75%22%20stroke-linecap%3D%22round%22%20stroke-linejoin%3D%22round%22%20vector-effect%3D%22non-scaling-stroke%22%20style%3D%22paint-order:%20stroke%20fill%22%20/><path%20d%3D%22M7.33%2C0V24h8.33V0Zm4.22%2C10h0a1.48%2C1.48%2C0%2C0%2C1-1.48-1.48h0A1.48%2C1.48%2C0%2C0%2C1%2C11.55%2C7h0A1.48%2C1.48%2C0%2C0%2C1%2C13%2C8.52h0A1.48%2C1.48%2C0%2C0%2C1%2C11.55%2C10Z%22%20fill%3D%22%23000000%22%20stroke%3D%22%23ffffff%22%20stroke-width%3D%221.75%22%20stroke-linecap%3D%22round%22%20stroke-linejoin%3D%22round%22%20vector-effect%3D%22non-scaling-stroke%22%20style%3D%22paint-order:%20stroke%20fill%22%20/></svg>" width="16" style="vertical-align:-4px;" />), and drag and click to select an interesting region in the spectrum. We can retrieve this region with the user-defined subset mask:

# %%
# Returns the data used by the app as specutils.Spectrum object
spectrum_data = jd.datasets[data_label].get_data()

# Returns the specutils.Spectrum object that contains a mask 
# attribute to represent the subset
spectrum_data_with_mask = jd.datasets[data_label].get_data(spectral_subset='Subset 1')

# Extract the mask from the returned object
subset_as_mask = spectrum_data_with_mask.mask

# Apply the mask to the spectral axis to produce the 'masked region'
# NOTE: using either spectrum_data or spectrum_data_with_mask produces
# the same result.
subset_as_region = spectrum_data_with_mask.spectral_axis[~subset_as_mask]

# This region is regarded as 'approximate' because it's bounds are limited 
# by the discretization of the spectral axis. The following cell retrieves
# the 'true' bounds.
print(f'Your subset spans from approximately {subset_as_region[0]:.4f} to {subset_as_region[-1]:.4f}.')

# %% [markdown]
# And to retrieve the subset from the **Subset Tools** plugin as a `specutils.SpectralRegion` object,

# %%
spectral_region = jd.plugins['Subset Tools'].get_regions()['Subset 1']
print(f'Your subset spans from {spectral_region.bounds[0]:.4f} to {spectral_region.bounds[-1]:.4f}.')

# %% [markdown]
# ## Export Viewer Image
#
# This can be done in the API as follows or by clicking on the **Export** icon (<!-- ../jdaviz/data/icons/content-save.svg --><img src="data:image/svg+xml;utf8,<svg%20xmlns%3D%22http://www.w3.org/2000/svg%22%20viewBox%3D%220%200%2024%2024%22><path%20d%3D%22M15%2C9H5V5H15M12%2C19A3%2C3%200%200%2C1%209%2C16A3%2C3%200%200%2C1%2012%2C13A3%2C3%200%200%2C1%2015%2C16A3%2C3%200%200%2C1%2012%2C19M17%2C3H5C3.89%2C3%203%2C3.9%203%2C5V19A2%2C2%200%200%2C0%205%2C21H19A2%2C2%200%200%2C0%2021%2C19V7L17%2C3Z%22%20fill%3D%22%23000000%22%20stroke%3D%22%23ffffff%22%20stroke-width%3D%221.75%22%20stroke-linecap%3D%22round%22%20stroke-linejoin%3D%22round%22%20vector-effect%3D%22non-scaling-stroke%22%20style%3D%22paint-order:%20stroke%20fill%22%20/></svg>" width="16" style="vertical-align:-4px;" />) and proceeding from there.

# %%
exp = jd.plugins['Export']
exp.viewer = '1D Spectrum'
exp.filename = f'{data_label}.png'
print(f'Exported to: {exp.export(overwrite=True)}')

# %% [markdown]
# ## Pan/Zoom
# You can use modify the field of view of the spectrum viewer by setting its limits. You can provide it a scalar (which assumes the units of the loaded spectra) or an `astropy.Quantity`.

# %%
viewer = jd.viewers['1D Spectrum']
viewer.set_limits(x_min=5.2, x_max=5.6, y_max=170.0)

# %% [markdown]
# ### Enable/Disable Scientific Notation
# Scientific notation is can be used in the axes of the viewers. To activate it, run the following code:

# %%
# fmt can be '0.1e' to set scientific notation
viewer.set_tick_format(fmt='0.1e', axis='x')

# %% [markdown]
# And to return to floating point:

# %%
# '0.2f' to turn it off
viewer.set_tick_format(fmt='0.2f', axis='x')

# %% [markdown]
# ### Reset Zoom
# You can also quickly return to the default zoom,

# %%
viewer.reset_limits()

# %% [markdown]
# ## Extract Models
# If models were added using the model fitting plugin, they can be extracted using the following property,

# %%
model_fitting = jd.plugins['Model Fitting']
model_fitting.fitted_models

# %% [markdown]
# If the name of a particular model is known, it can be extracted from the `fitted_models` property,

# %%
model_name = 'model'
model_fitting.fitted_models.get(model_name, f"No models named '{model_name}' have been fit to the data.")
